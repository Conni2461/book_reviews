# %%
from sqlalchemy import create_engine, Column, Date, String, Integer, Float, exc, and_, or_
from sqlalchemy.orm import Session, declarative_base

import requests

from selectorlib import Extractor
import requests
import json
from time import sleep
import random
import re

# %%
engine = create_engine("sqlite+pysqlite:///books.sqlite")
Base = declarative_base()
Base.metadata.create_all(engine)
session = Session(engine)

# %%
N = 3


def similarity(set1:set, set2:set, thresh = 0.8):
    #print(len(set1.intersection(set2)) / len(set1.union(set2)))
    try:
        return (len(set1.intersection(set2)) / len(set1.union(set2))) > thresh
    except:
        return 0

def similarity_complete(text1:String, text2:String, thresh = 0.8):

    set1 = set([text1.lower()[i:i+N] for i in range(len(text1)-N+1)])
    set2 = set([text2.lower()[i:i+N] for i in range(len(text2)-N+1)])
    #print(text1)
    #print(text2)
    return similarity(set1, set2, thresh)

# %%
class Amazon(Base):
    __tablename__ = 'Amazon'

    isbn = Column(String, primary_key=True)
    title = Column(String)
    subtitle = Column(String)
    author = Column(String)
    description = Column(String)
    book_type = Column(String)
    price = Column(Float)
    rating = Column(Float)
    review_count = Column(Integer)
    page_count = Column(Integer)
    language = Column(String)
    publisher = Column(String)
    published_date = Column(String)
    url = Column(String)


class Goodread(Base):
    __tablename__ = 'Goodreads'

    isbn = Column(String, primary_key=True)
    rating = Column(Float)
    rating_count = Column(Integer)
    review_count = Column(Integer)


class GoogleBook(Base):
    __tablename__ = 'GoogleBooks'

    isbn = Column(String, primary_key=True)
    title = Column(String)
    subtitle = Column(String)
    authors = Column(String)
    description = Column(String)
    categories = Column(String)
    average_rating = Column(Float)
    rating_count = Column(Integer)
    maturity_rating = Column(String)
    language = Column(Integer)
    page_count = Column(Integer)
    publisher = Column(String)
    published_date = Column(String)


class NYT(Base):
    __tablename__ = 'NYT'

    isbn = Column(String, primary_key=True)
    title = Column(String, nullable=False)
    author = Column(String, nullable=False)
    score = Column(Integer, nullable=False)
    publisher = Column(String, nullable=False)
    book_image = Column(String)
    amazon_product_url = Column(String)


class MergedBooksUpdated(Base):
    __tablename__ = 'merged_books_updated'

    isbn = Column(String, primary_key=True)
    title = Column(String, nullable=False)
    author = Column(String, nullable=False)
    publisher = Column(String)
    published_date = Column(String)
    description = Column(String)
    maturity_rating = Column(Integer)
    book_type = Column(String)
    price = Column(Float)
    page_count = Column(Integer)
    score_nyt = Column(Integer)
    goodreads_rating = Column(Float)
    goodreads_count = Column(Integer)
    amazon_rating = Column(Float)
    amazon_count = Column(Integer)
    google_rating = Column(Float)
    google_count = Column(Integer)
    book_image = Column(String)
    amazon_link = Column(String)

# %%
for book in session.query(NYT).all():

    isbn = book.isbn

    nyt = session.query(NYT).filter(NYT.isbn == isbn).first()
    amazon = session.query(Amazon).filter(Amazon.isbn == isbn).first()
    goodread = session.query(Goodread).filter(Goodread.isbn == isbn).first()
    googlebook = session.query(GoogleBook).filter(GoogleBook.isbn == isbn).first()



    isbn = nyt.isbn

    title = nyt.title
    if amazon.title != None and  not similarity_complete(nyt.title, amazon.title, 0.5):
        title += f"\nAlternate: {amazon.title}"
    if googlebook.title != None and not similarity_complete(nyt.title, googlebook.title, 0.5):
        title += f"\nAlternate: {googlebook.title}"


    author = nyt.author
    if amazon.author != None and not similarity_complete(nyt.author, amazon.author, 0.5):
        author += f"\nAlternate: {amazon.author}"
    if googlebook.authors != None and not similarity_complete(nyt.author, googlebook.authors, 0.5):
        author += f"\nAlternate: {googlebook.authors}"

    publisher = nyt.publisher
    if amazon.publisher != None and not similarity_complete(nyt.publisher, amazon.publisher, 0.5):
        publisher += f"\nAlternate: {amazon.publisher}"
    if googlebook.publisher != None and not similarity_complete(nyt.publisher, googlebook.publisher, 0.5):
        publisher += f"\nAlternate: {googlebook.publisher}"


    
   
    published_date = amazon.published_date
    description = googlebook.description
    maturity_rating = googlebook.maturity_rating
    book_type = amazon.book_type
    price = amazon.price

    page_count = amazon.page_count
    if page_count == None:
        page_count = googlebook.page_count

    score_nyt = nyt.score

    goodreads_rating = goodread.rating
    goodreads_count = goodread.rating_count

    amazon_rating = amazon.rating
    amazon_count = amazon.review_count

    google_rating = googlebook.average_rating
    google_count = googlebook.rating_count

    book_image = nyt.book_image
    amazon_link = nyt.amazon_product_url

    book = MergedBooksUpdated(
    isbn = isbn,
    title = title,
    author = author,
    publisher = publisher,
    published_date = published_date,
    description = description,
    maturity_rating = maturity_rating,
    book_type = book_type,
    price = price,
    page_count = page_count,
    score_nyt = score_nyt,
    goodreads_rating = goodreads_rating,
    goodreads_count = goodreads_count,
    amazon_rating = amazon_rating,
    amazon_count =amazon_count,
    google_rating = google_rating,
    google_count = google_count,
    book_image = book_image,
    amazon_link = amazon_link
    )

    session.add(book)
    session.commit()
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1798                 if not evt_handled:
# -> 1799                     self.dialect.do_execute(
#    1800                         cursor, statement, parameters, context
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     716     def do_execute(self, cursor, statement, parameters, context=None):
# --> 717         cursor.execute(statement, parameters)
#     718
#
# IntegrityError: UNIQUE constraint failed: merged_books_updated.isbn
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1404/3419301072.py in <module>
#      81
#      82     session.add(book)
# ---> 83     session.commit()
#
# ~\anaconda3\lib\site-packages\sqlalchemy\orm\session.py in commit(self)
#    1426                 raise sa_exc.InvalidRequestError("No transaction is begun.")
#    1427
# -> 1428         self._transaction.commit(_to_root=self.future)
#    1429
#    1430     def prepare(self):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\orm\session.py in commit(self, _to_root)
#     827         self._assert_active(prepared_ok=True)
#     828         if self._state is not PREPARED:
# --> 829             self._prepare_impl()
#     830
#     831         if self._parent is None or self.nested:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\orm\session.py in _prepare_impl(self)
#     806                 if self.session._is_clean():
#     807                     break
# --> 808                 self.session.flush()
#     809             else:
#     810                 raise exc.FlushError(
#
# ~\anaconda3\lib\site-packages\sqlalchemy\orm\session.py in flush(self, objects)
#    3338         try:
#    3339             self._flushing = True
# -> 3340             self._flush(objects)
#    3341         finally:
#    3342             self._flushing = False
#
# ~\anaconda3\lib\site-packages\sqlalchemy\orm\session.py in _flush(self, objects)
#    3478         except:
#    3479             with util.safe_reraise():
# -> 3480                 transaction.rollback(_capture_exception=True)
#    3481
#    3482     def bulk_save_objects(
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\orm\session.py in _flush(self, objects)
#    3438             self._warn_on_events = True
#    3439             try:
# -> 3440                 flush_context.execute()
#    3441             finally:
#    3442                 self._warn_on_events = False
#
# ~\anaconda3\lib\site-packages\sqlalchemy\orm\unitofwork.py in execute(self)
#     454         else:
#     455             for rec in topological.sort(self.dependencies, postsort_actions):
# --> 456                 rec.execute(self)
#     457
#     458     def finalize_flush_changes(self):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\orm\unitofwork.py in execute(self, uow)
#     628     @util.preload_module("sqlalchemy.orm.persistence")
#     629     def execute(self, uow):
# --> 630         util.preloaded.orm_persistence.save_obj(
#     631             self.mapper,
#     632             uow.states_for_mapper_hierarchy(self.mapper, False, False),
#
# ~\anaconda3\lib\site-packages\sqlalchemy\orm\persistence.py in save_obj(base_mapper, states, uowtransaction, single)
#     242         )
#     243
# --> 244         _emit_insert_statements(
#     245             base_mapper,
#     246             uowtransaction,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\orm\persistence.py in _emit_insert_statements(base_mapper, uowtransaction, mapper, table, insert, bookkeeping)
#    1094             multiparams = [rec[2] for rec in records]
#    1095
# -> 1096             c = connection._execute_20(
#    1097                 statement, multiparams, execution_options=execution_options
#    1098             )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_20(self, statement, parameters, execution_options)
#    1609             )
#    1610         else:
# -> 1611             return meth(self, args_10style, kwargs_10style, execution_options)
#    1612
#    1613     def exec_driver_sql(
#
# ~\anaconda3\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     323     ):
#     324         if _force or self.supports_execution:
# --> 325             return connection._execute_clauseelement(
#     326                 self, multiparams, params, execution_options
#     327             )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1476             linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1477         )
# -> 1478         ret = self._execute_context(
#    1479             dialect,
#    1480             dialect.execution_ctx_cls._init_compiled,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1840
#    1841         except BaseException as e:
# -> 1842             self._handle_dbapi_exception(
#    1843                 e, statement, parameters, cursor, context
#    1844             )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2021                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2022             elif should_wrap:
# -> 2023                 util.raise_(
#    2024                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2025                 )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1797                             break
#    1798                 if not evt_handled:
# -> 1799                     self.dialect.do_execute(
#    1800                         cursor, statement, parameters, context
#    1801                     )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     715
#     716     def do_execute(self, cursor, statement, parameters, context=None):
# --> 717         cursor.execute(statement, parameters)
#     718
#     719     def do_execute_no_params(self, cursor, statement, context=None):
#
# IntegrityError: (sqlite3.IntegrityError) UNIQUE constraint failed: merged_books_updated.isbn
# [SQL: INSERT INTO merged_books_updated (isbn, title, author, publisher, published_date, description, maturity_rating, book_type, price, page_count, score_nyt, goodreads_rating, goodreads_count, amazon_rating, amazon_count, google_rating, google_count, book_image, amazon_link) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)]
# [parameters: ('9781984818515', 'BETTER OFF DEAD\nAlternate: Better Off Dead A Jack Reacher Novel', 'Lee Child and Andrew Child\nAlternate: Lee Child', 'Delacorte', 'October 26, 2021', "#1 NEW YORK TIMES BESTSELLER • Jack Reacher is back in a brand-new page-turning thriller from acclaimed #1 bestselling authors Lee Child and Andrew C ... (1053 characters truncated) ... doncker down will be the riskiest job of Reacher's life. Failure is not an option, because in this kind of game, the loser is always better off dead.", 'NOT_MATURE', 'Hardcover', 17.03, '336 pages', 15, None, None, 4.1, 4275, 3.5, 6, 'https://storage.googleapis.com/du-prd/books/images/9781984818508.jpg', 'https://www.amazon.com/dp/1984818503?tag=NYTBSREV-20')]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)

# %%
session.rollback()

# %%
class MergedBooksAggregatedUpdated(Base):
    __tablename__ = 'merged_books_aggregated_updated'

    isbn = Column(String, primary_key=True)
    title = Column(String, nullable=False)
    author = Column(String, nullable=False)
    publisher = Column(String)
    published_date = Column(String)
    description = Column(String)
    maturity_rating = Column(Integer)
    book_type = Column(String)
    price = Column(Float)
    page_count = Column(Integer)
    score_nyt = Column(Integer)
    goodreads_rating = Column(Float)
    goodreads_count = Column(Integer)
    amazon_rating = Column(Float)
    amazon_count = Column(Integer)
    google_rating = Column(Float)
    google_count = Column(Integer)
    book_image = Column(String)
    amazon_link = Column(String)
    id_flag = Column(Integer)

# %%
#sort on title so that we can later use blocking
books = session.query(MergedBooksUpdated).order_by(MergedBooksUpdated.title).all()

# %%
finished_books = set()


#blocking where we use a window size of 10 on neighboorhoods which are sorted by title
for count, book1 in enumerate(books):
    print(book1.title)
    
    if book1 in finished_books:
        continue
    relevant_books = [book1]
    print(f"{book.title}, {book.author}")
    grams_title = set([book1.title[i:i+N] for i in range(len(book1.title)-N+1)])
    grams_author = set([book1.author[i:i+N] for i in range(len(book1.author)-N+1)])
    
    for book2 in books[count:count+10]:
        print(book2.title)
        grams_title2 = set([book2.title[i:i+N] for i in range(len(book2.title)-N+1)])
        grams_author2 = set([book2.author[i:i+N] for i in range(len(book2.author)-N+1)])

        if similarity(grams_title, grams_title2) & similarity(grams_author, grams_author2, 0.5):
            books.append(book2)
            finished_books.add(book2)
            
        
    for book in relevant_books:
        session.add(
        MergedBooksAggregatedUpdated(
        isbn = book.isbn,
        title = book.title,
        author = book.author,
        publisher = book.publisher,
        published_date = book.published_date,
        description = book.description,
        maturity_rating = book.maturity_rating,
        book_type = book.book_type,
        price = book.price,
        page_count = book.page_count,
        score_nyt = book.score_nyt,
        goodreads_rating = book.goodreads_rating,
        goodreads_count = book.goodreads_count,
        amazon_rating = book.amazon_rating,
        amazon_count = book.amazon_count,
        google_rating = book.google_rating,
        google_count = book.google_count,
        book_image = book.book_image,
        amazon_link = book.amazon_link,
        id_flag = count
        )
        )
    
    session.commit()
# Out:
# 'TIL DEATH DO US PART
# 'TIL DEATH DO US PART, Amanda Quick
# 'TIL DEATH DO US PART
# 10TH ANNIVERSARY
# Alternate: 10th Anniversary (Women's Murder Club, 10)
# 11/22/63
# Alternate: 11/22/63: A Novel
# 11/22/63
# Alternate: 11/22/63: A Novel
# 11/22/63
# Alternate: 11/22/63: A Novel
# 1105 YAKIMA STREET
# Alternate: 1
# 1105 YAKIMA STREET
# Alternate: 1
# 113 MINUTES
# Alternate: 113 Minutes (BookShots)
# 11TH HOUR
# Alternate: 11th Hour (Women's Murder Club, 11)
# 1225 CHRISTMAS TREE LANE
# 10TH ANNIVERSARY
# Alternate: 10th Anniversary (Women's Murder Club, 10)
# 'TIL DEATH DO US PART, Amanda Quick
# 10TH ANNIVERSARY
# Alternate: 10th Anniversary (Women's Murder Club, 10)
# 11/22/63
# Alternate: 11/22/63: A Novel
# 11/22/63
# Alternate: 11/22/63: A Novel
# 11/22/63
# Alternate: 11/22/63: A Novel
# 1105 YAKIMA STREET
# Alternate: 1
# 1105 YAKIMA STREET
# Alternate: 1
# 113 MINUTES
# Alternate: 113 Minutes (BookShots)
# 11TH HOUR
# Alternate: 11th Hour (Women's Murder Club, 11)
# 1225 CHRISTMAS TREE LANE
# 12TH OF NEVER
# Alternate: 12th of Never (Women's Murder Club, 12)
# 11/22/63
# Alternate: 11/22/63: A Novel
# 10TH ANNIVERSARY
# Alternate: 10th Anniversary (Women's Murder Club, 10), James Patterson and Maxine Paetro
# Alternate: James Patterson
# 11/22/63
# Alternate: 11/22/63: A Novel
# 11/22/63
# Alternate: 11/22/63: A Novel
# 11/22/63
# Alternate: 11/22/63: A Novel
# 1105 YAKIMA STREET
# Alternate: 1
# 1105 YAKIMA STREET
# Alternate: 1
# 113 MINUTES
# Alternate: 113 Minutes (BookShots)
# 11TH HOUR
# Alternate: 11th Hour (Women's Murder Club, 11)
# 1225 CHRISTMAS TREE LANE
# 12TH OF NEVER
# Alternate: 12th of Never (Women's Murder Club, 12)
# 14TH DEADLY SIN
# Alternate: 14th Deadly Sin (Women's Murder Club, 14)
# 11/22/63
# Alternate: 11/22/63: A Novel
# 11/22/63
# Alternate: 11/22/63: A Novel
# 1105 YAKIMA STREET
# Alternate: 1
# 11/22/63
# Alternate: 11/22/63: A Novel, Stephen King
# 1105 YAKIMA STREET
# Alternate: 1
# 1105 YAKIMA STREET
# Alternate: 1
# 113 MINUTES
# Alternate: 113 Minutes (BookShots)
# 11TH HOUR
# Alternate: 11th Hour (Women's Murder Club, 11)
# 1225 CHRISTMAS TREE LANE
# 12TH OF NEVER
# Alternate: 12th of Never (Women's Murder Club, 12)
# 14TH DEADLY SIN
# Alternate: 14th Deadly Sin (Women's Murder Club, 14)
# 15TH AFFAIR
# Alternate: 15th Affair (Women's Murder Club, 15)
# 16 LIGHTHOUSE ROAD
# Alternate: 16 LIGHTHOUSE ROAD (A Cedar Cove Novel Book 1)
# 16TH SEDUCTION
# Alternate: 16th Seduction (Women's Murder Club)
# 1105 YAKIMA STREET
# Alternate: 1
# 113 MINUTES
# Alternate: 113 Minutes (BookShots)
# 1105 YAKIMA STREET
# Alternate: 1, Debbie Macomber
# 113 MINUTES
# Alternate: 113 Minutes (BookShots)
# 11TH HOUR
# Alternate: 11th Hour (Women's Murder Club, 11)
# 1225 CHRISTMAS TREE LANE
# 12TH OF NEVER
# Alternate: 12th of Never (Women's Murder Club, 12)
# 14TH DEADLY SIN
# Alternate: 14th Deadly Sin (Women's Murder Club, 14)
# 15TH AFFAIR
# Alternate: 15th Affair (Women's Murder Club, 15)
# 16 LIGHTHOUSE ROAD
# Alternate: 16 LIGHTHOUSE ROAD (A Cedar Cove Novel Book 1)
# 16TH SEDUCTION
# Alternate: 16th Seduction (Women's Murder Club)
# 16TH SEDUCTION
# Alternate: 16th Seduction (Women's Murder Club)
# 1Q84
# Alternate: 1Q84 (Vintage International)
# 11TH HOUR
# Alternate: 11th Hour (Women's Murder Club, 11)
# 113 MINUTES
# Alternate: 113 Minutes (BookShots), James Patterson with Max DiLallo
# Alternate: James Patterson
# 11TH HOUR
# Alternate: 11th Hour (Women's Murder Club, 11)
# 1225 CHRISTMAS TREE LANE
# 12TH OF NEVER
# Alternate: 12th of Never (Women's Murder Club, 12)
# 14TH DEADLY SIN
# Alternate: 14th Deadly Sin (Women's Murder Club, 14)
# 15TH AFFAIR
# Alternate: 15th Affair (Women's Murder Club, 15)
# 16 LIGHTHOUSE ROAD
# Alternate: 16 LIGHTHOUSE ROAD (A Cedar Cove Novel Book 1)
# 16TH SEDUCTION
# Alternate: 16th Seduction (Women's Murder Club)
# 16TH SEDUCTION
# Alternate: 16th Seduction (Women's Murder Club)
# 1Q84
# Alternate: 1Q84 (Vintage International)
# 1ST CASE
# 1225 CHRISTMAS TREE LANE
# 11TH HOUR
# Alternate: 11th Hour (Women's Murder Club, 11), James Patterson and Maxine Paetro
# Alternate: James Patterson
# 1225 CHRISTMAS TREE LANE
# 12TH OF NEVER
# Alternate: 12th of Never (Women's Murder Club, 12)
# 14TH DEADLY SIN
# Alternate: 14th Deadly Sin (Women's Murder Club, 14)
# 15TH AFFAIR
# Alternate: 15th Affair (Women's Murder Club, 15)
# 16 LIGHTHOUSE ROAD
# Alternate: 16 LIGHTHOUSE ROAD (A Cedar Cove Novel Book 1)
# 16TH SEDUCTION
# Alternate: 16th Seduction (Women's Murder Club)
# 16TH SEDUCTION
# Alternate: 16th Seduction (Women's Murder Club)
# 1Q84
# Alternate: 1Q84 (Vintage International)
# 1ST CASE
# 1ST CASE
# 12TH OF NEVER
# Alternate: 12th of Never (Women's Murder Club, 12)
# 1225 CHRISTMAS TREE LANE, Debbie Macomber
# 12TH OF NEVER
# Alternate: 12th of Never (Women's Murder Club, 12)
# 14TH DEADLY SIN
# Alternate: 14th Deadly Sin (Women's Murder Club, 14)
# 15TH AFFAIR
# Alternate: 15th Affair (Women's Murder Club, 15)
# 16 LIGHTHOUSE ROAD
# Alternate: 16 LIGHTHOUSE ROAD (A Cedar Cove Novel Book 1)
# 16TH SEDUCTION
# Alternate: 16th Seduction (Women's Murder Club)
# 16TH SEDUCTION
# Alternate: 16th Seduction (Women's Murder Club)
# 1Q84
# Alternate: 1Q84 (Vintage International)
# 1ST CASE
# 1ST CASE
# 2 SISTERS DETECTIVE AGENCY
# 14TH DEADLY SIN
# Alternate: 14th Deadly Sin (Women's Murder Club, 14)
# 12TH OF NEVER
# Alternate: 12th of Never (Women's Murder Club, 12), James Patterson and Maxine Paetro
# Alternate: James Patterson
# 14TH DEADLY SIN
# Alternate: 14th Deadly Sin (Women's Murder Club, 14)
# 15TH AFFAIR
# Alternate: 15th Affair (Women's Murder Club, 15)
# 16 LIGHTHOUSE ROAD
# Alternate: 16 LIGHTHOUSE ROAD (A Cedar Cove Novel Book 1)
# 16TH SEDUCTION
# Alternate: 16th Seduction (Women's Murder Club)
# 16TH SEDUCTION
# Alternate: 16th Seduction (Women's Murder Club)
# 1Q84
# Alternate: 1Q84 (Vintage International)
# 1ST CASE
# 1ST CASE
# 2 SISTERS DETECTIVE AGENCY
# 2 SISTERS DETECTIVE AGENCY
# 15TH AFFAIR
# Alternate: 15th Affair (Women's Murder Club, 15)
# 14TH DEADLY SIN
# Alternate: 14th Deadly Sin (Women's Murder Club, 14), James Patterson and Maxine Paetro
# Alternate: James Patterson
# 15TH AFFAIR
# Alternate: 15th Affair (Women's Murder Club, 15)
# 16 LIGHTHOUSE ROAD
# Alternate: 16 LIGHTHOUSE ROAD (A Cedar Cove Novel Book 1)
# 16TH SEDUCTION
# Alternate: 16th Seduction (Women's Murder Club)
# 16TH SEDUCTION
# Alternate: 16th Seduction (Women's Murder Club)
# 1Q84
# Alternate: 1Q84 (Vintage International)
# 1ST CASE
# 1ST CASE
# 2 SISTERS DETECTIVE AGENCY
# 2 SISTERS DETECTIVE AGENCY
# 2034
# Alternate: 2034: A Novel of the Next World War
# 16 LIGHTHOUSE ROAD
# Alternate: 16 LIGHTHOUSE ROAD (A Cedar Cove Novel Book 1)
# 15TH AFFAIR
# Alternate: 15th Affair (Women's Murder Club, 15), James Patterson and Maxine Paetro
# Alternate: James Patterson
# 16 LIGHTHOUSE ROAD
# Alternate: 16 LIGHTHOUSE ROAD (A Cedar Cove Novel Book 1)
# 16TH SEDUCTION
# Alternate: 16th Seduction (Women's Murder Club)
# 16TH SEDUCTION
# Alternate: 16th Seduction (Women's Murder Club)
# 1Q84
# Alternate: 1Q84 (Vintage International)
# 1ST CASE
# 1ST CASE
# 2 SISTERS DETECTIVE AGENCY
# 2 SISTERS DETECTIVE AGENCY
# 2034
# Alternate: 2034: A Novel of the Next World War
# 21ST BIRTHDAY
# Alternate: 21st Birthday (Women's Murder Club, 21)
# 16TH SEDUCTION
# Alternate: 16th Seduction (Women's Murder Club)
# 
# TWO BY TWO
# TWO BY TWO
# TWO BY TWO
# TWO GRAVES
# Alternate: Two Graves (Pendergast Book 12)
# TWO KINDS OF TRUTH
# Alternate: Two Kinds of Truth (A Harry Bosch Novel Book 20)
# TWO KINDS OF TRUTH
# Alternate: Two Kinds of Truth (A Harry Bosch Novel Book 20)
# TWO NIGHTS
# Alternate: Two Nights: A Novel
# TWO OF A KIND
# Alternate: Two of a Kind (Fool's Gold Book 11)
# TWO WEEKS
# Alternate: Two Weeks: A Novel (Baxter Family)
# TYPHOON FURY
# Alternate: Typhoon Fury (The Oregon Files Book 12)
# TYPHOON FURY
# Alternate: Typhoon Fury (The Oregon Files Book 12)
# UGLY LOVE
# Alternate: Ugly Love: A Novel
# UNBOUND
# Alternate: Unbound (A Stone Barrington Novel Book 44)
# UNCOMMON TYPE
# Alternate: Uncommon Type: Some Stories
# UNCOMPROMISING HONOR
# Alternate: Uncompromising Honor (19) (Honor Harrington)
# UNDER A VAMPIRE MOON
# Alternate: Under a Vampire Moon: An Argeneau Novel
# UNDER CURRENTS
# UNDER CURRENTS
# Alternate: -11
# UNDER THE WHISPERING DOOR
# UNDERCOVER
# Alternate: Undercover: A Novel
# UNFINISHED BUSINESS
# Alternate: -1
# UNFINISHED BUSINESS
# Alternate: 0
# UNFINISHED BUSINESS
# Alternate: 1
# UNINTENDED CONSEQUENCES
# Alternate: Unintended Consequences (Stone Barrington, Book 26) (A Stone Barrington Novel)
# UNLOCKED
# Alternate: Unlocked (The Alpha Group Trilogy #3)
# UNLUCKY 13
# Alternate: Unlucky 13 (Women's Murder Club, 13)
# UNNATURAL ACTS
# Alternate: Unnatural Acts: A Stone Barrington Novel
# UNRAVELED
# Alternate: Unraveled (Steel Brothers Saga Book 9)
# UNSEEN
# Alternate: Unseen (with bonus novella "Busted"): A Novel (Will Trent)
# Alternate: Unseen (with bonus novella "Busted")
# UNSHELTERED
# Alternate: Unsheltered: A Novel
# UNSOLVED
# Alternate: Unsolved (Invisible, 2)
# UNTIL JULY
# Alternate: Until July (Until Her Book 1)
# UNTIL JUNE
# UNTIL PROVEN GUILTY
# Alternate: Until Proven Guilty (J. P. Beaumont Novel Book 1)
# UNTIL THE END OF TIME
# UNTIL WE TOUCH
# Alternate: Until We Touch (Fool's Gold Book 16)
# UNTO US A SON IS GIVEN
# Alternate: Unto Us a Son Is Given (A Commissario Guido Brunetti Mystery Book 28)
# UNTOUCHABLE
# UP FROM THE GRAVE
# Alternate: Up from the Grave (Night Huntress)
# UPSIDE DOWN
# Alternate: Upside Down (The Men of the Sisterhood Book 1)
# USE OF FORCE
# Alternate: Use of Force: A Thriller (The Scot Harvath Series Book 16)
# USE OF FORCE
# Alternate: Use of Force: A Thriller (The Scot Harvath Series Book 16)
# UTOPIA AVENUE
# V IS FOR VENGEANCE
# Alternate: V is for Vengeance: A Kinsey Millhone Novel
# V IS FOR VENGEANCE
# Alternate: V is for Vengeance: A Kinsey Millhone Novel
# VALENTINE
# Alternate: Valentine: A Novel
# VAMPIRE MOST WANTED
# Alternate: Vampire Most Wanted: An Argeneau Novel
# VAMPIRES LIKE IT HOT
# Alternate: Vampires Like It Hot: An Argeneau Novel
# VENDETTA
# Alternate: Vendetta: A Novel
# VENDETTA IN DEATH
# Alternate: Vendetta in Death: An Eve Dallas Novel
# VENDETTA ROAD
# Alternate: Vendetta Road (Torpedo Ink Book 3)
# VENGEANCE ROAD
# Alternate: Vengeance Road (Torpedo Ink Book 2)
# VENGEANCE ROAD
# Alternate: Vengeance Road (Torpedo Ink Book 2)
# VERITY
# VERONICA MARS: MR. KISS AND TELL
# Alternate: Veronica Mars 2: An Original Mystery by Rob Thomas: Mr. Kiss and Tell
# Alternate: Veronica Mars 2: An Original Mystery by Rob Thomas
# VERONICA MARS: THE THOUSAND-DOLLAR TAN LINE
# Alternate: Veronica Mars: An Original Mystery by Rob Thomas
# VERSES FOR THE DEAD
# Alternate: Verses for the Dead (Agent Pendergast Series, 18)
# VICIOUS CIRCLE
# Alternate: Vicious Circle (A Joe Pickett Novel Book 17)
# VICIOUS CIRCLE
# Alternate: Vicious Circle (A Joe Pickett Novel Book 17)
# VICTIMS
# Alternate: Victims (Alex Delaware)
# VICTORY AND HONOR
# Alternate: Victory and Honor (HONOR BOUND Book 6)
# VINCE FLYNN: ENEMY AT THE GATES
# Alternate: Enemy at the Gates (20) (A Mitch Rapp Novel)
# VINCE FLYNN: ENEMY AT THE GATES
# Alternate: Enemy at the Gates (20) (A Mitch Rapp Novel)
# VINCE FLYNN: LETHAL AGENT
# Alternate: Lethal Agent (Mitch Rapp Book 18)
# Alternate: Lethal Agent
# VINCE FLYNN: ORDER TO KILL
# Alternate: Order to Kill: A Novel (Mitch Rapp Book 15)
# Alternate: Order to Kill
# VINCE FLYNN: ORDER TO KILL
# Alternate: Order to Kill: A Novel (Mitch Rapp Book 15)
# Alternate: Order to Kill
# VINCE FLYNN: RED WAR
# Alternate: Red War (Mitch Rapp Book 17)
# Alternate: Red War
# VINCE FLYNN: RED WAR
# Alternate: Red War (Mitch Rapp Book 17)
# Alternate: Red War
# VINCE FLYNN: TOTAL POWER
# Alternate: Total Power (19) (A Mitch Rapp Novel)
# Alternate: Total Power
# VINCE FLYNN: TOTAL POWER
# Alternate: Total Power (19) (A Mitch Rapp Novel)
# Alternate: Total Power
# VIOLET BENT BACKWARDS OVER THE GRASS
# VIPER GAME
# Alternate: Viper Game (Ghostwalker Novel Book 11)
# VIRGINS
# Alternate: Virgins: An Outlander Novella (Kindle Single)
# Alternate: Virgins: An Outlander Novella
# VISCOUNT BRECKENRIDGE TO THE RESCUE
# Alternate: Viscount Breckenridge to the Rescue: A Cynster Novel (Cynster Sisters Trilogy, 1)
# VORTEX
# Alternate: Vortex: An FBI Thriller (An FBI Thriller, 25)
# W IS FOR WASTED
# Alternate: W is for Wasted: A Kinsey Millhone Novel
# WAIT FOR ME
# Alternate: Wait For Me (Against All Odds Book 1)
# WAIT FOR YOU
# Alternate: Wait for You (Wait for You Saga, 1)
# WAITING FOR LOVE
# Alternate: Waiting for Love (Gansett Island Series Book 8)
# Alternate: Waiting for Love (Gansett Island Series, Book 8)
# WALK THE WIRE
# Alternate: Walk the Wire (Memory Man Series, 6)
# WALK THE WIRE
# Alternate: Walk the Wire (Memory Man Series, 6)
# WALK THE WIRE
# Alternate: Walk the Wire (Memory Man Series, 6)
# Alternate: David Baldacci Spring 2020
# WALK THROUGH FIRE
# Alternate: Walk Through Fire (The Chaos Series Book 4)
# WALKING DISASTER
# Alternate: Walking Disaster: A Novel (Beautiful Book 2)
# WALKING ON WATER
# WANTED
# Alternate: Wanted: A Most Wanted Novel
# WAR LORD
# Alternate: War Lord: A Novel (Saxon Tales, 13)
# WAR OF THE SPARK: RAVNICA
# Alternate: Ravnica
# WAR OF THE WOLF
# Alternate: War of the Wolf: A Novel (Saxon Tales Book 11)
# WARDS OF FAERIE
# Alternate: Wards of Faerie: The Dark Legacy of Shannara
# WARLIGHT
# Alternate: Warlight: A novel
# WARRIORS OF THE STORM
# Alternate: Warriors of the Storm: A Novel (Saxon Tales, 9)
# WATER FOR ELEPHANTS
# WATER FOR ELEPHANTS
# WATER FOR ELEPHANTS
# WAYFARING STRANGER
# Alternate: Wayfaring Stranger: A Novel (A Holland Family Novel)
# WE ARE NOT OURSELVES
# WE ARE WATER
# WE BEGIN AT THE END
# WE SHOULDN'T
# WE WERE NEVER HERE
# WEDDING CAKE MURDER
# Alternate: Wedding Cake Murder (Hannah Swensen Book 19)
# WEDDING NIGHT
# WELCOME TO NIGHT VALE
# WELL HUNG
# Alternate: Well Hung (Big Rock Book 3)
# WHAT DOESN'T KILL YOU
# WHAT HAPPENS IN PARADISE
# WHAT HAPPENS IN PARADISE
# WHAT IT WAS
# Alternate: What It Was (Derek Strange and Terry Quinn Series Book 5)
# WHAT SHE KNEW
# WHAT WE FIND
# Alternate: What We Find (Sullivan's Crossing Book 1)
# WHEN AUGUST ENDS
# WHEN DAY BREAKS
# Alternate: When Day Breaks (KGI series Book 9)
# WHEN HE WAS WICKED
# Alternate: When He Was Wicked (Bridgertons Book 6)
# WHEN I'M GONE
# Alternate: When I'm Gone: A Rosemary Beach Novel (The Rosemary Beach Series Book 11)
# WHEN LIFE GIVES YOU LULULEMONS
# WHEN THE STARS GO DARK
# WHEN WE MET
# Alternate: When We Met (Fool's Gold Book 14)
# WHEN YOU SEE ME
# Alternate: When You See Me: A Novel (D.D. Warren Book 11)
# WHERE AZALEAS BLOOM
# Alternate: Where Azaleas Bloom (A Sweet Magnolias Novel, 10)
# WHERE I BELONG
# Alternate: Where I Belong (Alabama Summer Book 1)
# WHERE THE CRAWDADS SING
# WHERE THE CRAWDADS SING
# WHERE THE CRAWDADS SING
# WHERE WE BELONG
# WHERE WINTER FINDS YOU
# Alternate: Where Winter Finds You: A Caldwell Christmas (The Black Dagger Brotherhood series
# WHEREABOUTS
# Alternate: Whereabouts: A novel
# WHILE JUSTICE SLEEPS
# WHISKEY BEACH
# WHITE FIRE
# Alternate: White Fire (Agent Pendergast Series, 13)
# WHITE HOT
# Alternate: White Hot: A Hidden Legacy Novel
# WHITE IVY
# Alternate: White Ivy: A Novel
# Alternate: Wolf Rain (Psy-Changeling Trinity Book 3)
# WOMAN OF GOD
# WOMAN OF GOD
# WOOL OMNIBUS EDITION
# Alternate: Wool Omnibus Edition [Kindle in Motion] (Silo series Book 1)
# WORDS OF RADIANCE
# Alternate: Words of Radiance (The Stormlight Archive, Book 2)
# WORLD WAR Z
# Alternate: World War Z (Mass Market Movie Tie-In Edition): An Oral History of the Zombie War
# WORTH DYING FOR
# Alternate: Worth Dying For (Jack Reacher)
# WORTH THE FIGHT
# Alternate: Worth the Fight (MMA Fighter Series Book 1)
# WRATH
# Alternate: 1
# WRATH OF POSEIDON
# Alternate: Wrath of Poseidon (A Sam and Remi Fargo Adventure)
# WRITERS & LOVERS
# WRITTEN IN MY OWN HEART'S BLOOD
# Alternate: Written in My Own Heart's Blood: A Novel (Outlander, Book 8)
# WRITTEN IN MY OWN HEART'S BLOOD
# Alternate: Written in My Own Heart's Blood: A Novel (Outlander, Book 8)
# WRONG
# Alternate: Wrong (Cafe Series Book 1)
# WRONG BED, RIGHT GUY
# WYOMING BOLD
# WYOMING LEGEND
# Alternate: Wyoming Legend (Wyoming Men Book 8)
# WYOMING WINTER
# Alternate: Wyoming Winter: A Small-Town Christmas Romance (Wyoming Men)
# Alternate: Wyoming Christmas
# X
# Alternate: X (Kinsey Millhone Book 24)
# Alternate: X
# Y IS FOR YESTERDAY
# Alternate: Y is for Yesterday (A Kinsey Millhone Novel Book 25)
# Y IS FOR YESTERDAY
# Alternate: Y is for Yesterday (A Kinsey Millhone Novel Book 25)
# YEAR ONE
# Alternate: Year One: Chronicles of The One, Book 1 (Chronicles of The One, 1)
# YEAR ONE
# Alternate: Year One: Chronicles of The One, Book 1 (Chronicles of The One, 1)
# YOU ARE NOT ALONE
# YOU DO SOMETHING TO ME
# Alternate: You Do Something To Me (New York Sullivans) (The Sullivans Book 17)
# Alternate: You Do Something To Me (New York Sullivans)
# YOU DON'T OWN ME
# Alternate: You Don't Own Me (Under Suspicion Book 6)
# YOU DON'T OWN ME
# Alternate: You Don't Own Me (Under Suspicion Book 6)
# YOU DON’T WANT TO KNOW
# YOU LOVE ME
# Alternate: You Love Me: A You Novel
# YOU SAY IT FIRST
# Alternate: You Say It First: A Small-Town Wedding Romance (Happily Inc Book 1)
# YOU SHOULD HAVE KNOWN
# Alternate: The Undoing: Previously Published as You Should Have Known: The Most Talked About TV Series of 2020, Now on HBO
# Alternate: The Undoing: Previously Published as You Should Have Known
# YOU WERE MINE
# Alternate: You Were Mine: A Rosemary Beach Novel (The Rosemary Beach Series Book 9)
# YOU WILL PAY
# YOUR LOVE IS MINE
# Alternate: Your Love Is Mine (Maine Sullivans 1) (The Sullivans Book 19)
# Alternate: Your Love Is Mine: Maine Sullivans 1
# YOUR NEXT BREATH
# YOURS FOR CHRISTMAS
# ZERO DAY
# Alternate: Zero Day (John Puller Series)
# ZERO HOUR
# Alternate: Zero Hour (The NUMA Files)
# ZOO
# ZOO
# ZOO 2
# Alternate: Zoo 2 (BookShots)
