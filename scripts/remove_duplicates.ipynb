# %%
from sqlalchemy import create_engine, Column, Date, String, Integer, Float, exc, and_, or_
from sqlalchemy.orm import Session, declarative_base

import requests

from selectorlib import Extractor
import requests
import json
from time import sleep
import random
import re

# %%
engine = create_engine("sqlite+pysqlite:///books.sqlite")
Base = declarative_base()
Base.metadata.create_all(engine)
session = Session(engine)

# %%
N = 3


def similarity(set1:set, set2:set, thresh = 0.8):
    #print(len(set1.intersection(set2)) / len(set1.union(set2)))
    try:
        return (len(set1.intersection(set2)) / len(set1.union(set2))) > thresh
    except:
        return 0

def similarity_complete(text1:String, text2:String, thresh = 0.8):

    set1 = set([text1.lower()[i:i+N] for i in range(len(text1)-N+1)])
    set2 = set([text2.lower()[i:i+N] for i in range(len(text2)-N+1)])
    #print(text1)
    #print(text2)
    return similarity(set1, set2, thresh)

# %%
class Amazon(Base):
    __tablename__ = 'Amazon'

    isbn = Column(String, primary_key=True)
    title = Column(String)
    subtitle = Column(String)
    author = Column(String)
    description = Column(String)
    book_type = Column(String)
    price = Column(Float)
    rating = Column(Float)
    review_count = Column(Integer)
    page_count = Column(Integer)
    language = Column(String)
    publisher = Column(String)
    published_date = Column(String)
    url = Column(String)


class Goodread(Base):
    __tablename__ = 'Goodreads'

    isbn = Column(String, primary_key=True)
    rating = Column(Float)
    rating_count = Column(Integer)
    review_count = Column(Integer)


class GoogleBook(Base):
    __tablename__ = 'GoogleBooks'

    isbn = Column(String, primary_key=True)
    title = Column(String)
    subtitle = Column(String)
    authors = Column(String)
    description = Column(String)
    categories = Column(String)
    average_rating = Column(Float)
    rating_count = Column(Integer)
    maturity_rating = Column(String)
    language = Column(Integer)
    page_count = Column(Integer)
    publisher = Column(String)
    published_date = Column(String)


class NYT(Base):
    __tablename__ = 'NYT'

    isbn = Column(String, primary_key=True)
    title = Column(String, nullable=False)
    author = Column(String, nullable=False)
    score = Column(Integer, nullable=False)
    publisher = Column(String, nullable=False)
    book_image = Column(String)
    amazon_product_url = Column(String)


class MergedBooksUpdated(Base):
    __tablename__ = 'merged_books_updated'

    isbn = Column(String, primary_key=True)
    title = Column(String, nullable=False)
    author = Column(String, nullable=False)
    publisher = Column(String)
    published_date = Column(String)
    description = Column(String)
    maturity_rating = Column(Integer)
    book_type = Column(String)
    price = Column(Float)
    page_count = Column(Integer)
    score_nyt = Column(Integer)
    goodreads_rating = Column(Float)
    goodreads_count = Column(Integer)
    amazon_rating = Column(Float)
    amazon_count = Column(Integer)
    google_rating = Column(Float)
    google_count = Column(Integer)
    book_image = Column(String)
    amazon_link = Column(String)

# %%
for book in session.query(NYT).all():

    isbn = book.isbn

    nyt = session.query(NYT).filter(NYT.isbn == isbn).first()
    amazon = session.query(Amazon).filter(Amazon.isbn == isbn).first()
    goodread = session.query(Goodread).filter(Goodread.isbn == isbn).first()
    googlebook = session.query(GoogleBook).filter(GoogleBook.isbn == isbn).first()



    isbn = nyt.isbn

    title = nyt.title
    if amazon.title != None and  not similarity_complete(nyt.title, amazon.title, 0.5):
        title += f"\nAlternate: {amazon.title}"
    if googlebook.title != None and not similarity_complete(nyt.title, googlebook.title, 0.5):
        title += f"\nAlternate: {googlebook.title}"


    author = nyt.author
    if amazon.author != None and not similarity_complete(nyt.author, amazon.author, 0.5):
        author += f"\nAlternate: {amazon.author}"
    if googlebook.authors != None and not similarity_complete(nyt.author, googlebook.authors, 0.5):
        author += f"\nAlternate: {googlebook.authors}"

    publisher = nyt.publisher
    if amazon.publisher != None and not similarity_complete(nyt.publisher, amazon.publisher, 0.5):
        publisher += f"\nAlternate: {amazon.publisher}"
    if googlebook.publisher != None and not similarity_complete(nyt.publisher, googlebook.publisher, 0.5):
        publisher += f"\nAlternate: {googlebook.publisher}"


    
   
    published_date = amazon.published_date
    description = googlebook.description
    maturity_rating = googlebook.maturity_rating
    book_type = amazon.book_type
    price = amazon.price

    page_count = amazon.page_count
    if page_count == None:
        page_count = googlebook.page_count

    score_nyt = nyt.score

    goodreads_rating = goodread.rating
    goodreads_count = goodread.rating_count

    amazon_rating = amazon.rating
    amazon_count = amazon.review_count

    google_rating = googlebook.average_rating
    google_count = googlebook.rating_count

    book_image = nyt.book_image
    amazon_link = nyt.amazon_product_url

    book = MergedBooksUpdated(
    isbn = isbn,
    title = title,
    author = author,
    publisher = publisher,
    published_date = published_date,
    description = description,
    maturity_rating = maturity_rating,
    book_type = book_type,
    price = price,
    page_count = page_count,
    score_nyt = score_nyt,
    goodreads_rating = goodreads_rating,
    goodreads_count = goodreads_count,
    amazon_rating = amazon_rating,
    amazon_count =amazon_count,
    google_rating = google_rating,
    google_count = google_count,
    book_image = book_image,
    amazon_link = amazon_link
    )

    session.add(book)
    session.commit()
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1798                 if not evt_handled:
# -> 1799                     self.dialect.do_execute(
#    1800                         cursor, statement, parameters, context
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     716     def do_execute(self, cursor, statement, parameters, context=None):
# --> 717         cursor.execute(statement, parameters)
#     718
#
# IntegrityError: UNIQUE constraint failed: merged_books_updated.isbn
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18036/3419301072.py in <module>
#      81
#      82     session.add(book)
# ---> 83     session.commit()
#
# ~\anaconda3\lib\site-packages\sqlalchemy\orm\session.py in commit(self)
#    1426                 raise sa_exc.InvalidRequestError("No transaction is begun.")
#    1427
# -> 1428         self._transaction.commit(_to_root=self.future)
#    1429
#    1430     def prepare(self):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\orm\session.py in commit(self, _to_root)
#     827         self._assert_active(prepared_ok=True)
#     828         if self._state is not PREPARED:
# --> 829             self._prepare_impl()
#     830
#     831         if self._parent is None or self.nested:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\orm\session.py in _prepare_impl(self)
#     806                 if self.session._is_clean():
#     807                     break
# --> 808                 self.session.flush()
#     809             else:
#     810                 raise exc.FlushError(
#
# ~\anaconda3\lib\site-packages\sqlalchemy\orm\session.py in flush(self, objects)
#    3338         try:
#    3339             self._flushing = True
# -> 3340             self._flush(objects)
#    3341         finally:
#    3342             self._flushing = False
#
# ~\anaconda3\lib\site-packages\sqlalchemy\orm\session.py in _flush(self, objects)
#    3478         except:
#    3479             with util.safe_reraise():
# -> 3480                 transaction.rollback(_capture_exception=True)
#    3481
#    3482     def bulk_save_objects(
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\orm\session.py in _flush(self, objects)
#    3438             self._warn_on_events = True
#    3439             try:
# -> 3440                 flush_context.execute()
#    3441             finally:
#    3442                 self._warn_on_events = False
#
# ~\anaconda3\lib\site-packages\sqlalchemy\orm\unitofwork.py in execute(self)
#     454         else:
#     455             for rec in topological.sort(self.dependencies, postsort_actions):
# --> 456                 rec.execute(self)
#     457
#     458     def finalize_flush_changes(self):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\orm\unitofwork.py in execute(self, uow)
#     628     @util.preload_module("sqlalchemy.orm.persistence")
#     629     def execute(self, uow):
# --> 630         util.preloaded.orm_persistence.save_obj(
#     631             self.mapper,
#     632             uow.states_for_mapper_hierarchy(self.mapper, False, False),
#
# ~\anaconda3\lib\site-packages\sqlalchemy\orm\persistence.py in save_obj(base_mapper, states, uowtransaction, single)
#     242         )
#     243
# --> 244         _emit_insert_statements(
#     245             base_mapper,
#     246             uowtransaction,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\orm\persistence.py in _emit_insert_statements(base_mapper, uowtransaction, mapper, table, insert, bookkeeping)
#    1094             multiparams = [rec[2] for rec in records]
#    1095
# -> 1096             c = connection._execute_20(
#    1097                 statement, multiparams, execution_options=execution_options
#    1098             )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_20(self, statement, parameters, execution_options)
#    1609             )
#    1610         else:
# -> 1611             return meth(self, args_10style, kwargs_10style, execution_options)
#    1612
#    1613     def exec_driver_sql(
#
# ~\anaconda3\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     323     ):
#     324         if _force or self.supports_execution:
# --> 325             return connection._execute_clauseelement(
#     326                 self, multiparams, params, execution_options
#     327             )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1476             linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1477         )
# -> 1478         ret = self._execute_context(
#    1479             dialect,
#    1480             dialect.execution_ctx_cls._init_compiled,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1840
#    1841         except BaseException as e:
# -> 1842             self._handle_dbapi_exception(
#    1843                 e, statement, parameters, cursor, context
#    1844             )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2021                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2022             elif should_wrap:
# -> 2023                 util.raise_(
#    2024                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2025                 )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1797                             break
#    1798                 if not evt_handled:
# -> 1799                     self.dialect.do_execute(
#    1800                         cursor, statement, parameters, context
#    1801                     )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     715
#     716     def do_execute(self, cursor, statement, parameters, context=None):
# --> 717         cursor.execute(statement, parameters)
#     718
#     719     def do_execute_no_params(self, cursor, statement, context=None):
#
# IntegrityError: (sqlite3.IntegrityError) UNIQUE constraint failed: merged_books_updated.isbn
# [SQL: INSERT INTO merged_books_updated (isbn, title, author, publisher, published_date, description, maturity_rating, book_type, price, page_count, score_nyt, goodreads_rating, goodreads_count, amazon_rating, amazon_count, google_rating, google_count, book_image, amazon_link) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)]
# [parameters: ('9781984818515', 'BETTER OFF DEAD\nAlternate: Better Off Dead A Jack Reacher Novel', 'Lee Child and Andrew Child\nAlternate: Lee Child', 'Delacorte', 'October 26, 2021', "#1 NEW YORK TIMES BESTSELLER • Jack Reacher is back in a brand-new page-turning thriller from acclaimed #1 bestselling authors Lee Child and Andrew C ... (1053 characters truncated) ... doncker down will be the riskiest job of Reacher's life. Failure is not an option, because in this kind of game, the loser is always better off dead.", 'NOT_MATURE', 'Hardcover', 17.03, '336 pages', 15, None, None, 4.1, 4275, 3.5, 6, 'https://storage.googleapis.com/du-prd/books/images/9781984818508.jpg', 'https://www.amazon.com/dp/1984818503?tag=NYTBSREV-20')]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)

# %%
session.rollback()

# %%
class MergedBooksAggregatedUpdated(Base):
    __tablename__ = 'merged_books_aggregated_updated'

    isbn = Column(String, primary_key=True)
    title = Column(String, nullable=False)
    author = Column(String, nullable=False)
    publisher = Column(String)
    published_date = Column(String)
    description = Column(String)
    maturity_rating = Column(Integer)
    book_type = Column(String)
    price = Column(Float)
    page_count = Column(Integer)
    score_nyt = Column(Integer)
    goodreads_rating = Column(Float)
    goodreads_count = Column(Integer)
    amazon_rating = Column(Float)
    amazon_count = Column(Integer)
    google_rating = Column(Float)
    google_count = Column(Integer)
    book_image = Column(String)
    amazon_link = Column(String)
    id_flag = Column(Integer)

# %%
books = session.query(MergedBooksUpdated).all()

# %%
finished_books = set()
for count, book1 in enumerate(books):
    print(book1.title)
    
    if book1 in finished_books:
        continue
    relevant_books = [book1]
    #print(f"{book.title}, {book.author}")
    grams_title = set([book1.title[i:i+N] for i in range(len(book1.title)-N+1)])
    grams_author = set([book1.author[i:i+N] for i in range(len(book1.author)-N+1)])
    
    for book2 in books:
        print(book2.title)
        grams_title2 = set([book2.title[i:i+N] for i in range(len(book2.title)-N+1)])
        grams_author2 = set([book2.author[i:i+N] for i in range(len(book2.author)-N+1)])

        if similarity(grams_title, grams_title2) & similarity(grams_author, grams_author2, 0.5):
            books.append(book2)
            finished_books.add(book2)
            
        
    for book in relevant_books:
        session.add(
        MergedBooksAggregatedUpdated(
        isbn = book.isbn,
        title = book.title,
        author = book.author,
        publisher = book.publisher,
        published_date = book.published_date,
        description = book.description,
        maturity_rating = book.maturity_rating,
        book_type = book.book_type,
        price = book.price,
        page_count = book.page_count,
        score_nyt = book.score_nyt,
        goodreads_rating = book.goodreads_rating,
        goodreads_count = book.goodreads_count,
        amazon_rating = book.amazon_rating,
        amazon_count = book.amazon_count,
        google_rating = book.google_rating,
        google_count = book.google_count,
        book_image = book.book_image,
        amazon_link = book.amazon_link,
        id_flag = count
        )
        )
    
    session.commit()
# Out:
# BETTER OFF DEAD
# Alternate: Better Off Dead A Jack Reacher Novel
# BETTER OFF DEAD
# Alternate: Better Off Dead A Jack Reacher Novel
# THE JUDGE'S LIST
# Alternate: The Judge's List: A Novel (The Whistler)
# DUNE
# Alternate: Dune (Movie Tie-In)
# THE LINCOLN HIGHWAY
# THE WISH
# Alternate: New Novel by Nicholas Sparks
# IT ENDS WITH US
# APPLES NEVER FALL
# STATE OF TERROR
# CLOUD CUCKOO LAND
# THE SEVEN HUSBANDS OF EVELYN HUGO
# ARCHANGEL'S LIGHT
# Alternate: Archangel's Light (A Guild Hunter Novel)
# FORGIVING PARIS
# THE LAST THING HE TOLD ME
# THE LOVE HYPOTHESIS
# THE MIDNIGHT LIBRARY
# DEAR SANTA
# Alternate: Dear Santa: A Novel
# OH WILLIAM!
# Alternate: Oh William!: A Novel
# SILVERVIEW
# Alternate: Silverview: A Novel
# OVER MY DEAD BODY
# Alternate: Over My Dead Body: A Novel (William Warwick Novels)
# Alternate: Over My Dead Body (William Warwick Novels)
# THE BOOK OF MAGIC
# Alternate: The Book of Magic: A Novel (4) (The Practical Magic Series)
# VERITY
# THE BUTLER
# Alternate: The Butler: A Novel
# 2 SISTERS DETECTIVE AGENCY
# HARLEM SHUFFLE
# CROSSROADS
# Alternate: Crossroads: A Novel
# 2 SISTERS DETECTIVE AGENCY
# FOUL PLAY
# Alternate: Foul Play (A Stone Barrington Novel)
# ALL THE LIGHT WE CANNOT SEE
# THE JAILHOUSE LAWYER
# THE LAST GRADUATE
# Alternate: The Last Graduate: A Novel (The Scholomance)
# THE MAN WHO DIED TWICE
# Alternate: The Man Who Died Twice: A Thursday Murder Club Mystery
# VINCE FLYNN: ENEMY AT THE GATES
# Alternate: Enemy at the Gates (20) (A Mitch Rapp Novel)
# BEWILDERMENT
# THE SANTA SUIT
# MILE HIGH WITH A VAMPIRE
# Alternate: Mile High with a Vampire (An Argeneau Novel, 33)
# BILLY SUMMERS
# DAUGHTER OF THE MORNING STAR
# UNDER THE WHISPERING DOOR
# BEAUTIFUL WORLD, WHERE ARE YOU
# A SLOW FIRE BURNING
# WHERE THE CRAWDADS SING
# APPLES NEVER FALL
# VINCE FLYNN: ENEMY AT THE GATES
# Alternate: Enemy at the Gates (20) (A Mitch Rapp Novel)
# FORGOTTEN IN DEATH
# Alternate: Forgotten in Death: An Eve Dallas Novel (In Death, 53)
# THE LOVE HYPOTHESIS
# THE WISDOM OF CROWDS
# Alternate: Sunflower Sisters: A Novel (Woolsey-Ferriday)
# THE CONSEQUENCES OF FEAR
# Alternate: The Consequences of Fear: A Maisie Dobbs Novel (Maisie Dobbs, 16)
# DOUBLE JEOPARDY
# Alternate: Double Jeopardy (A Stone Barrington Novel)
# THE BOUNTY
# Alternate: The Bounty: A Novel (7) (A Fox and O'Hare Novel)
# ETERNAL
# LIFE AFTER DEATH
# WE BEGIN AT THE END
# WIN
# WILD SIGN
# Alternate: Wild Sign (Alpha and Omega)
# DARK SKY
# Alternate: Dark Sky (A Joe Pickett Novel)
# CAMINO WINDS
# FAST ICE
# Alternate: Fast Ice (The NUMA Files)
# 2034
# Alternate: 2034: A Novel of the Next World War
# THE AFFAIR
# Alternate: The Affair: A Novel
# TRANSIENT DESIRES
# Alternate: Transient Desires: A Commissario Guido Brunetti Mystery (The Commissario Guido Brunetti Mysteries, 30)
# THE VISCOUNT WHO LOVED ME
# Alternate: Viscount Who Loved Me, The (Bridgertons Book 2)
# DARK SKY
# Alternate: Dark Sky (A Joe Pickett Novel)
# THE UNDERGROUND RAILROAD
# Alternate: The Underground Railroad (Pulitzer Prize Winner) (National Book Award Winner) (Oprah's Book Club): A Novel
# LIGHTNING GAME
# Alternate: Lightning Game (A GhostWalker Novel)
# FIREFLY LANE
# THE KAISER'S WEB
# Alternate: The Kaiser's Web: A Novel (Cotton Malone, 16)
# A COURT OF SILVER FLAMES
# Alternate: A Court of Silver Flames (A Court of Thorns and Roses, 5)
# KINGDOM OF SHADOW AND LIGHT
# THE SANATORIUM
# TRIPLE CHOCOLATE CHEESECAKE MURDER
# Alternate: Triple Chocolate Cheesecake Murder: An Entertaining & Delicious Cozy Mystery with Recipes (A Hannah Swensen Mystery)
# AN OFFER FROM A GENTLEMAN
# Alternate: Offer From a Gentleman, An (Bridgertons Book 3)
# FAITHLESS IN DEATH
# Alternate: Faithless in Death: An Eve Dallas Novel (In Death, 52)
# WHERE THE CRAWDADS SING
# RELENTLESS
# Alternate: Relentless (Gray Man)
# THE DUKE AND I
# Alternate: The Duke and I: The (Bridgertons Book 1)
# Alternate: Bridgerton
# MISSING AND ENDANGERED
# Alternate: Missing and Endangered: A Brady Novel of Suspense
# THE VISCOUNT WHO LOVED ME
# Alternate: Viscount Who Loved Me, The (Bridgertons Book 2)
# THE RUSSIAN
# Alternate: The Russian (Michael Bennett, 13)
# ROMANCING MISTER BRIDGERTON
# FAITHLESS IN DEATH
# Alternate: Faithless in Death: An Eve Dallas Novel (In Death, 52)
# RECKLESS ROAD
# Alternate: Reckless Road (Torpedo Ink)
# RAFAEL
# Alternate: Rafael (Anita Blake, Vampire Hunter)
# THE PARIS LIBRARY
# THE SURVIVORS
# SERPENTINE
# Alternate: Serpentine: An Alex Delaware Novel
# SEND FOR ME
# Alternate: Send for Me: A novel
# AN OFFER FROM A GENTLEMAN
# Alternate: Offer From a Gentleman, An (Bridgertons Book 3)
# ANXIOUS PEOPLE
# THE RUSSIAN
# Alternate: The Russian (Michael Bennett, 13)
# THE PUSH
# Alternate: The Push: A Novel
# HIGHLAND TREASURE
# Alternate: Highland Treasure: Highland Brides (Highland Brides, 9)
# Alternate: Leopard's Rage (A Leopard Novel)
# MOONFLOWER MURDERS
# THE SEARCHER
# FORTUNE AND GLORY
# Alternate: Fortune and Glory: Tantalizing Twenty-Seven (27) (Stephanie Plum)
# THE SEARCHER
# WHITE IVY
# Alternate: White Ivy: A Novel
# THREE WOMEN DISAPPEAR
# Alternate: Three Women Disappear: With bonus novel Come and Get Us
# THE WONDER BOY OF WHISTLE STOP
# THE BOOK OF TWO WAYS
# THE DIRTY SOUTH
# Alternate: The Dirty South: A Thriller (18) (Charlie Parker)
# HIDDEN IN PLAIN SIGHT
# Alternate: Hidden in Plain Sight: A Detective William Warwick Novel (William Warwick Novels, 2)
# THE SENTINEL
# Alternate: The Sentinel: A Jack Reacher Novel
# THREE WOMEN DISAPPEAR
# Alternate: Three Women Disappear: With bonus novel Come and Get Us
# SHAKEUP
# Alternate: Shakeup (A Stone Barrington Novel)
# TRULY, MADLY, DEEPLY
# Alternate: Truly, Madly, Deeply: A Novel (The Baxter Family)
# THE NOEL LETTERS
# Alternate: The Noel Letters (The Noel Collection)
# MY LAST DUCHESS
# TROUBLES IN PARADISE
# Alternate: Troubles in Paradise (Volume 3) (Paradise, 3)
# MEXICAN GOTHIC
# LEAVE THE WORLD BEHIND
# THE LAST DRUID
# Alternate: The Last Druid (The Fall of Shannara)
# THE GUEST LIST
# A TIME FOR MERCY
# Alternate: A Time for Mercy (Jake Brigance)
# RETURN TO VIRGIN RIVER
# Alternate: Return to Virgin River: A Novel (A Virgin River Novel, 19)
# JINGLE ALL THE WAY
# INVISIBLE GIRL
# THE COAST-TO-COAST MURDERS
# TROUBLES IN PARADISE
# Alternate: Troubles in Paradise (Volume 3) (Paradise, 3)
# MAGIC LESSONS
# Alternate: Magic Lessons: The Prequel to Practical Magic (1) (The Practical Magic Series)
# WALK THE WIRE
# Alternate: Walk the Wire (Memory Man Series, 6)
# VINCE FLYNN: TOTAL POWER
# Alternate: Total Power (19) (A Mitch Rapp Novel)
# Alternate: Total Power
# BATTLE GROUND
# Alternate: Battle Ground (Dresden Files)
# VIOLET BENT BACKWARDS OVER THE GRASS
# VINCE FLYNN: TOTAL POWER
# Alternate: Total Power (19) (A Mitch Rapp Novel)
# Alternate: Total Power
# A DEADLY EDUCATION
# Alternate: A Deadly Education: A Novel (The Scholomance)
# IMMORTAL ANGEL
# Alternate: Immortal Angel: An Argeneau Novel (An Argeneau Novel, 31)
# CHRISTMAS CUPCAKE MURDER
# Alternate: Christmas Cupcake Murder: A Festive & Delicious Christmas Cozy Mystery (A Hannah Swensen Mystery)
# TROUBLED BLOOD
# Alternate: Troubled Blood (A Cormoran Strike Novel, 5)
# ONE BY ONE
# NEXT TO LAST STAND
# Alternate: Next to Last Stand: A Longmire Mystery
# ANXIOUS PEOPLE
# ALL THE DEVILS ARE HERE
# Alternate: All the Devils Are Here: A Novel (Chief Inspector Gamache Novel, 16)
# SHADOWS IN DEATH
# Alternate: Shadows in Death: An Eve Dallas Novel (In Death, 51)
# THE HARBINGER II
# Alternate: The Harbinger II: The Return (Harbinger, 2)
# AMERICAN DIRT
# Alternate: American Dirt (Oprah's Book Club): A Novel
# THE EVENING AND THE MORNING
# TO SLEEP IN A SEA OF STARS
# PIRANESI
# WALK THE WIRE
# Alternate: Walk the Wire (Memory Man Series, 6)
# THE LAST FLIGHT
# FAIR WARNING
# Alternate: Fair Warning (Jack McEvoy, 3)
# PARTY OF TWO
# HIDEAWAY
# Alternate: Hideaway: A Novel
# TOM CLANCY: FIRING POINT
# Alternate: Tom Clancy Firing Point (A Jack Ryan Jr. Novel)
# AMERICAN DEMON
# DEACON KING KONG
# DEVOLUTION
# Alternate: Devolution: A Firsthand Account of the Rainier Sasquatch Massacre
# THE SUMMER HOUSE
# DADDY'S GIRLS
# TOM CLANCY: FIRING POINT
# Alternate: Tom Clancy Firing Point (A Jack Ryan Jr. Novel)
# BIG SUMMER
# Alternate: Big Summer: A Novel
# WALK THE WIRE
# Alternate: Walk the Wire (Memory Man Series, 6)
# Alternate: David Baldacci Spring 2020
# DANCE AWAY WITH ME
# THE LIES THAT BIND
# BIG SUMMER
# Alternate: Big Summer: A Novel
# HUSH
# Alternate: Hush (Harriet Blue, 4)
# NORMAL PEOPLE
# ALL ADULTS HERE
# HIDEAWAY
# Alternate: Hideaway: A Novel
# FAIR WARNING
# Alternate: Fair Warning (Jack McEvoy, 3)
# WRATH OF POSEIDON
# Alternate: Wrath of Poseidon (A Sam and Remi Fargo Adventure)
# BOMBSHELL
# Alternate: Bombshell (A Teddy Fay Novel)
# ALL ADULTS HERE
# THE 20TH VICTIM
# Alternate: The 20th Victim (Women's Murder Club, 20)
# THE HENNA ARTIST
# Alternate: The Henna Artist: A Novel (The Jaipur Trilogy, 1)
# ON OCEAN BOULEVARD
# Alternate: On Ocean Boulevard (The Beach House)
# THE LAST TRIAL
# BEACH READ
# RODHAM
# Alternate: Rodham: A Novel
# A WEEK AT THE SHORE
# BLUE MOON
# Alternate: Blue Moon: A Jack Reacher Novel
# THE BOOK OF LOST FRIENDS
# THE WOMAN IN THE WINDOW
# THE SILENT PATIENT
# THE 20TH VICTIM
# Alternate: The 20th Victim (Women's Murder Club, 20)
# SHADOW FLIGHT
# Alternate: Shadow Flight (A Shadow Riders Novel)
# HELLO, SUMMER
# NETWORK EFFECT
# Alternate: Network Effect: A Murderbot Novel (The Murderbot Diaries, 5)
# THE BOOK OF LONGINGS
# THE WEDDING DRESS
# MASKED PREY
# Alternate: Masked Prey (A Prey Novel)
# THE END OF OCTOBER
# THE GIVER OF STARS
# MASKED PREY
# Alternate: Masked Prey (A Prey Novel)
# FIRST COMES SCANDAL
# Alternate: First Comes Scandal: A Bridgerton Prequel (A Bridgerton Prequel, 4)
# THE GIVER OF STARS
# IN FIVE YEARS
# THE BOY FROM THE WOODS
# THE DUTCH HOUSE
# THE LAST EMPEROX
# Alternate: The Last Emperox (The Interdependency, 3)
# THE WOMAN IN THE WINDOW
# THE TATTOOIST OF AUSCHWITZ
# SAVAGE SON
# Alternate: Savage Son: A Thriller (3) (Terminal List)
# THE GLASS HOTEL
# REDHEAD BY THE SIDE OF THE ROAD
# THE BOY FROM THE WOODS
# REVENGE
# EVERYTHING I NEVER TOLD YOU
# Alternate: Robert B. Parker's Colorblind (A Jesse Stone Novel Book 17)
# IN HIS FATHER'S FOOTSTEPS
# DARK SENTINEL
# Alternate: Dark Sentinel (The Dark Book 32)
# DEPTH OF WINTER
# Alternate: Depth of Winter: A Longmire Mystery
# FIELD OF BONES
# Alternate: Field of Bones: A Brady Novel of Suspense (Joanna Brady Mysteries Book 18)
# SHARP OBJECTS
# TEXAS RANGER
# Alternate: Texas Ranger (A Texas Ranger Thriller Book 1)
# THE PRESIDENT IS MISSING
# MAGIC TRIUMPHS
# Alternate: Magic Triumphs (Kate Daniels Book 10)
# THE FALL OF GONDOLIN
# THE GOVERNESS GAME
# Alternate: The Governess Game: Girl Meets Duke
# STYGIAN
# Alternate: Stygian: A Dark-Hunter Novel (Dark-Hunter Novels Book 27)
# ENEMY OF THE STATE
# Alternate: Enemy of the State (Mitch Rapp Book 16)
# THE AFFAIR
# Alternate: The Affair: A Jack Reacher Novel
# PIECES OF HER
# SMALL GREAT THINGS
# LESS
# Alternate: Less (Winner of the Pulitzer Prize): A Novel
# Alternate: Less (Winner of the Pulitzer Prize)
# INVISIBLE
# YEAR ONE
# Alternate: Year One: Chronicles of The One, Book 1 (Chronicles of The One, 1)
# DESOLATION MOUNTAIN
# Alternate: Desolation Mountain: A Novel (Cork O'Connor Mystery Series Book 17)
# TEXAS RANGER
# Alternate: Texas Ranger (A Texas Ranger Thriller Book 1)
# FEARED
# Alternate: Feared: A Rosato & DiNunzio Novel
# TAILSPIN
# THE ROOSTER BAR
# THE OTHER WOMAN
# Alternate: The Other Woman: A Novel (Gabriel Allon Book 18)
# THE OUTSIDER
# LESS
# Alternate: Less (Winner of the Pulitzer Prize): A Novel
# Alternate: Less (Winner of the Pulitzer Prize)
# RICHER THAN SIN
# Alternate: Richer Than Sin (Sin Trilogy Book 1)
# SERPENTINE
# Alternate: Serpentine (Anita Blake, Vampire Hunter Book 26)
# THE MONEY SHOT
# Alternate: The Money Shot (A Teddy Fay Novel Book 2)
# THE CHASE
# Alternate: The Chase (Briar U Book 1)
# PARADOX
# Alternate: Paradox (An FBI Thriller Book 22)
# YOU WILL PAY
# WILD LIKE THE WIND
# BORN TO BE WILDE
# Alternate: Born to Be Wilde: The Wildes of Lindow Castle
# PACHINKO
# Alternate: Pachinko (National Book Award Finalist)
# Alternate: Pachinko (National Book Award Finalist)
# DR. STRANGE BEARD
# Alternate: Dr. Strange Beard: A Small Town Romantic Comedy (Winston Brothers Book 5)
# COTTAGE BY THE SEA
# THE PERFECT COUPLE
# THRAWN: ALLIANCES
# Alternate: Thrawn: Alliances (Star Wars) (Star Wars: Thrawn)
# THE NAKED TRUTH
# ALL WE EVER WANTED
# GHOSTED
# Alternate: Ghosted: A Novel
# THE ADVENTURE ZONE: HERE THERE BE GERBLINS
# COTTAGE BY THE SEA
# ALL YOUR PERFECTS
# SPYMASTER
# Alternate: Spymaster: A Thriller (The Scot Harvath Series Book 17)
# TRIPLE HOMICIDE
# Alternate: Triple Homicide: From the case files of Alex Cross, Michael Bennett, and the Women's Murder Club
